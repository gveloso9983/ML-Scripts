# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
import matplotlib.pyplot as plt

#for replicability purposes
tf.random.set_seed(91195003)
#for an easy reset backend session state
tf.keras.backend.clear_session()

# %%
#Load dataset
def load_dataset(path=r'yahoo_stock.csv'):
  return pd.read_csv(path)

# %%
#split data into training and validation sets
def split_data(training, perc=10):
  train_idx = np.arange(0, int(len(training)*(100-perc)/100))
  val_idx = np.arange(int(len(training)*(100-perc)/100+1), len(training))
  return train_idx, val_idx

# %%
def prepare_data(df):
  df_aux = df.drop(columns=['High', 'Low', 'Volume', 'Adj Close'], inplace=False)
  df_aux = df_aux.set_index('Date')
  return df_aux

# %%
def data_normalization(df, norm_range=(-1, 1)):
  #[-1, 1] for LSTM due to the internal use of tanh by the memory cell
  scaler = MinMaxScaler(feature_range=norm_range)
  df[['Open']] = scaler.fit_transform(df[['Open']])
  df[['Close']] = scaler.fit_transform(df[['Close']])
  return scaler

# %%
#plot learning curve
def plot_learning_curves(history, epochs):
  #accuracies and losses
  #dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse'])
  loss=history.history['loss']
  val_loss=history.history['val_loss']
  epochs_range = range(epochs)
  #creating figure
  plt.figure(figsize=(8,8))
  plt.subplot(1,2,2)
  plt.plot(epochs_range,loss,label='Training Loss')
  plt.plot(epochs_range,val_loss,label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training/Validation Loss')
  plt.show()

# %%
#Plot time series data
def plot_confirmed_cases(data):
  plt.figure(figsize=(8,6))
  plt.plot(range(len(data)), data)
  plt.title('Confirmed Cases of COVID-19')
  plt.ylabel('Cases')
  plt.xlabel('Days')
  plt.show()

# %%
#Preparing the dataset for the LSTM
def to_supervised(df, timesteps):
  data = df.values
  X, y = list(), list()
  #iterate over the training set to create X and y
  dataset_size = len(data)
  for curr_pos in range(dataset_size):
    #end of the input sequence is the current position + the number of timesteps of the input sequence
    input_index = curr_pos + timesteps
    #end of the labels corresponds to the end of the input sequence + 1
    label_index = input_index + 1
    #if we have enough data for this sequence
    if label_index < dataset_size:
      X.append(data[curr_pos:input_index, :])
      y.append(data[input_index:label_index, 0])
  #using np.float32 for GPU performance
  return np.array(X).astype('float32'), np.array(y).astype('float32')

# %%
#Building the model
def rmse(y_true, y_pred):
  return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))

# %%
def build_model(timesteps, features, h_neurons=64, activation='tanh'):
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.LSTM(h_neurons, activation=activation, input_shape=(timesteps, features), return_sequences=True))
  #Add a new layer
  model.add(tf.keras.layers.LSTM(32, activation=activation ,return_sequences=False))
  #
  model.add(tf.keras.layers.Dense(h_neurons, activation=activation))
  model.add(tf.keras.layers.Dense(n_variate, activation='linear'))
  #model summary (and save it as PNG)
  tf.keras.utils.plot_model(model, 'yahoo_model.png', show_shapes=True)
  return model

# %%
#Compiling and fit the model
def compile_and_fit(model, epochs, batch_size):
  #compile
  model.compile(loss = rmse, optimizer = tf.keras.optimizers.Adam(), metrics = ['mae', rmse])
  #fit
  hist_list = list()
  loss_list = list()

  #callback
  #saving in Keras HDF5 (or h5), a binary data format
  callbacks = [tf.keras.callbacks.ModelCheckpoint(
        filepath='my_model_{epoch}_{val_loss:.3f}.h5',#path where to save model
        save_best_only=True,#overwrite the current checkpoint if and only if
        monitor='val_loss',#the val_loss score has improved
        save_weights_only=False,#if True, only the weigths are saved
        verbose=1,#verbosity mode
        period=5 #save ony at the fifth epoch (5 em 5 epocas) 
        )#,
    #interrupt training if loss stops improving for over 2 epochs
    #tf.keras.callbacks.EarlyStopping(patience=9, monitor='cost')
    ]

  #Time Series Cross Validator
  tscv = TimeSeriesSplit(n_splits=cv_splits)
  for train_index, test_index in tscv.split(X):
    train_idx, val_idx = split_data(train_index, perc=10) #further split into training and validation sets
    #build data
    X_train, y_train = X[train_idx], y[train_idx]
    X_val, y_val = X[val_idx], y[val_idx]
    X_test, y_test = X[test_index], y[test_index]

    #print("x_val::::",X_val,"\n","y_val:",y_val,"\n")

    history = model.fit(X_train, y_train, validation_data=(X_val, y_val),epochs=epochs, batch_size=batch_size, shuffle=False, callbacks=callbacks)
    metrics = model.evaluate(X_test, y_test)


    plot_learning_curves(history, epochs)
    hist_list.append(history)


  return model, hist_list

# %%
#Main Execution
#the dataframes
df_raw = load_dataset()
#Get data from 2015 to the end of 2018
df_raw = df_raw[:1134]
df_data = prepare_data(df_raw)
df = df_data.copy()

scaler = data_normalization(df) #scaling data to [-1, 1]

# %%
#load modelo forecast close
model_close = tf.keras.models.load_model('modelo_aux_close_9.h5', custom_objects={'rmse': rmse})# Show the model architecture
model_close.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 10, 64)            17152
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 31,810
# Trainable params: 31,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Recursive Multi-Step Forecast!!!
def forecast(model, df, timesteps, multisteps, scaler):
  input_seq = np.array(df[-timesteps:].values) #getting the last sequence of known value
  inp = input_seq
  #print("Input_seq: ",inp)
  forecasts = list()

  #multisteps tells us how many iterations we want to perform, i.e., how many days we want to predict
  for step in range(1, multisteps+1):
    inp = inp.reshape(1,timesteps,n_variate)
    yhat = model.predict(inp) #dá o valor predito do Open normalizado
    yhat_aux = model_close.predict(inp)  #dá o valor predito do Close normalizado
    yhat_desnormalized = scaler.inverse_transform(yhat) #dá valor predito desnormalizado
    forecasts.append(yhat_desnormalized) #adicionar previsao à lista final de previsões
    #preparar novo input para fazer previsão para o dia seguinte
    inp= np.append(inp[0],[[yhat[0][0],yhat_aux[0][0]]],axis=0)
    inp = inp[-timesteps:] #vai ao input buscar os ultimos timesteps registados
  return forecasts

# %%
def plot_forecast(data, forecasts):

  plt.figure(figsize=(8,6))
  plt.plot(range(len(data)), data['Open'], color='green', label='True value')
  plt.plot(range(len(data)-1, len(data)+len(forecasts)-1), forecasts, color='red', label='Forecasts')
  plt.title('Yahoo stock price')
  plt.ylabel('Value')
  plt.xlabel('Days')
  plt.legend()
  plt.show()

# %% [markdown]
# # Tunning

# %%
tunning_dict = {               
                1: {'timesteps' : 7, 'multisteps' : 15, 'cv_splits': 3, 'epochs' : 10,  'batch_size' : 5 },
                2: {'timesteps' : 7, 'multisteps' : 15, 'cv_splits' : 3, 'epochs' : 50,  'batch_size' : 5 },
                3: {'timesteps' : 7, 'multisteps' : 15, 'cv_splits' : 3, 'epochs' : 100,  'batch_size' : 5 },

                #
                4: {'timesteps' : 8, 'multisteps' : 15, 'cv_splits': 3, 'epochs' : 60,  'batch_size' : 5 },
                5: {'timesteps' : 8, 'multisteps' : 15, 'cv_splits' : 3, 'epochs' : 90,  'batch_size' : 5 },
                6: {'timesteps' : 8, 'multisteps' : 15, 'cv_splits' : 3, 'epochs' : 120,  'batch_size' : 5 },
                #
                7: {'timesteps' : 10, 'multisteps' : 15, 'cv_splits': 3, 'epochs' : 50,  'batch_size' : 8 },
                8: {'timesteps' : 10, 'multisteps' : 15, 'cv_splits' : 3, 'epochs' : 90,  'batch_size' : 8 },
                9: {'timesteps' : 10, 'multisteps' : 15, 'cv_splits' : 3, 'epochs' : 120,  'batch_size' : 8 }

}
# record da history de cada modelo
record = {}

# %%
n_variate = 2

# %%
for t in tunning_dict:
  #print(record[r])
  # fitting the model
  timesteps = tunning_dict[t]['timesteps']
  epochs = tunning_dict[t]['epochs']
  batch_size= tunning_dict[t]['batch_size']
  multisteps= tunning_dict[t]['multisteps']
  cv_splits = tunning_dict[t]['cv_splits']
  #print(timesteps,epochs,batch_size,cv_splits)

  X, y = to_supervised(df, timesteps)

  model = build_model(timesteps, n_variate)
  model, history = compile_and_fit(model, epochs, batch_size)
  #print("df: ",df.shape," timesteps",timesteps," multisteps ",multisteps)
  forecasts = forecast(model, df, timesteps, multisteps, scaler)

  print(forecasts)

  prev = []

  #plot do valor previsto da ação de Open
  for f in forecasts:
    prev.append(f[0][0])

  print(prev)
  plot_forecast(df_raw, prev)

  #Scorer
  

  record[t] = history
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/10
# 51/51 [==============================] - 5s 31ms/step - loss: 0.3206 - mae: 0.3159 - rmse: 0.3206 - val_loss: 0.0206 - val_mae: 0.0171 - val_rmse: 0.0203
# Epoch 2/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1177 - mae: 0.1121 - rmse: 0.1177 - val_loss: 0.0139 - val_mae: 0.0121 - val_rmse: 0.0136
# Epoch 3/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1676 - mae: 0.1622 - rmse: 0.1676 - val_loss: 0.0782 - val_mae: 0.0776 - val_rmse: 0.0785
# Epoch 4/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1238 - mae: 0.1195 - rmse: 0.1238 - val_loss: 0.0854 - val_mae: 0.0852 - val_rmse: 0.0857
# Epoch 5/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1187 - mae: 0.1151 - rmse: 0.1187 - val_loss: 0.0818 - val_mae: 0.0812 - val_rmse: 0.0821
#
# Epoch 00005: val_loss improved from inf to 0.08183, saving model to my_model_5_0.082.h5
# Epoch 6/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1200 - mae: 0.1165 - rmse: 0.1200 - val_loss: 0.0776 - val_mae: 0.0765 - val_rmse: 0.0779
# Epoch 7/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1274 - mae: 0.1241 - rmse: 0.1274 - val_loss: 0.0721 - val_mae: 0.0712 - val_rmse: 0.0724
# Epoch 8/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1288 - mae: 0.1256 - rmse: 0.1288 - val_loss: 0.0660 - val_mae: 0.0652 - val_rmse: 0.0662
# Epoch 9/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1310 - mae: 0.1279 - rmse: 0.1310 - val_loss: 0.0633 - val_mae: 0.0625 - val_rmse: 0.0635
# Epoch 10/10
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1307 - mae: 0.1277 - rmse: 0.1307 - val_loss: 0.0655 - val_mae: 0.0647 - val_rmse: 0.0658
#
# Epoch 00010: val_loss improved from 0.08183 to 0.06553, saving model to my_model_10_0.066.h5
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1984 - mae: 0.1953 - rmse: 0.2025
# Epoch 1/10
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0890 - mae: 0.0866 - rmse: 0.0888 - val_loss: 0.0271 - val_mae: 0.0248 - val_rmse: 0.0270
# Epoch 2/10
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1178 - mae: 0.1154 - rmse: 0.1172 - val_loss: 0.0412 - val_mae: 0.0392 - val_rmse: 0.0414
# Epoch 3/10
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0981 - mae: 0.0961 - rmse: 0.0978 - val_loss: 0.0273 - val_mae: 0.0247 - val_rmse: 0.0268
# Epoch 4/10
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0823 - mae: 0.0801 - rmse: 0.0820 - val_loss: 0.0224 - val_mae: 0.0207 - val_rmse: 0.0217
# Epoch 5/10
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0772 - mae: 0.0740 - rmse: 0.0769 - val_loss: 0.0375 - val_mae: 0.0354 - val_rmse: 0.0374
#
# Epoch 00005: val_loss improved from 0.06553 to 0.03752, saving model to my_model_5_0.038.h5
# Epoch 6/10
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0769 - mae: 0.0741 - rmse: 0.0766 - val_loss: 0.0258 - val_mae: 0.0243 - val_rmse: 0.0254
# Epoch 7/10
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0743 - mae: 0.0721 - rmse: 0.0739 - val_loss: 0.0346 - val_mae: 0.0327 - val_rmse: 0.0344
# Epoch 8/10
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0700 - mae: 0.0676 - rmse: 0.0698 - val_loss: 0.0316 - val_mae: 0.0299 - val_rmse: 0.0314
# Epoch 9/10
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0685 - mae: 0.0662 - rmse: 0.0682 - val_loss: 0.0340 - val_mae: 0.0318 - val_rmse: 0.0338
# Epoch 10/10
# 102/102 [==============================] - 1s 8ms/step - loss: 0.0669 - mae: 0.0645 - rmse: 0.0666 - val_loss: 0.0337 - val_mae: 0.0316 - val_rmse: 0.0335
#
# Epoch 00010: val_loss improved from 0.03752 to 0.03368, saving model to my_model_10_0.034.h5
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2061 - mae: 0.2013 - rmse: 0.2095
# Epoch 1/10
# 152/152 [==============================] - 3s 7ms/step - loss: 0.0541 - mae: 0.0509 - rmse: 0.0541 - val_loss: 0.0609 - val_mae: 0.0539 - val_rmse: 0.0614
# Epoch 2/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0377 - mae: 0.0351 - rmse: 0.0377 - val_loss: 0.0733 - val_mae: 0.0664 - val_rmse: 0.0730
# Epoch 3/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0340 - mae: 0.0304 - rmse: 0.0340 - val_loss: 0.0686 - val_mae: 0.0609 - val_rmse: 0.0685
# Epoch 4/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0319 - mae: 0.0289 - rmse: 0.0319 - val_loss: 0.0634 - val_mae: 0.0553 - val_rmse: 0.0634
# Epoch 5/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0319 - mae: 0.0289 - rmse: 0.0319 - val_loss: 0.0657 - val_mae: 0.0580 - val_rmse: 0.0656
#
# Epoch 00005: val_loss did not improve from 0.03368
# Epoch 6/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0358 - mae: 0.0326 - rmse: 0.0358 - val_loss: 0.0682 - val_mae: 0.0612 - val_rmse: 0.0679
# Epoch 7/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0365 - mae: 0.0334 - rmse: 0.0365 - val_loss: 0.0635 - val_mae: 0.0567 - val_rmse: 0.0633
# Epoch 8/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0360 - mae: 0.0332 - rmse: 0.0360 - val_loss: 0.0602 - val_mae: 0.0538 - val_rmse: 0.0601
# Epoch 9/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0351 - mae: 0.0324 - rmse: 0.0351 - val_loss: 0.0559 - val_mae: 0.0500 - val_rmse: 0.0559
# Epoch 10/10
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0340 - mae: 0.0316 - rmse: 0.0340 - val_loss: 0.0626 - val_mae: 0.0564 - val_rmse: 0.0623
#
# Epoch 00010: val_loss did not improve from 0.03368
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0856 - mae: 0.0767 - rmse: 0.0857
# WARNING:tensorflow:Model was constructed with shape (None, 10, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10, 2), dtype=tf.float32, name='lstm_16_input'), name='lstm_16_input', description="created by layer 'lstm_16_input'"), but it was called on an input with incompatible shape (None, 7, 2).
# [array([[2509.8472, 2519.6692]], dtype=float32), array([[2519.2393, 2529.9639]], dtype=float32), array([[2531.17  , 2541.9785]], dtype=float32), array([[2543.2441, 2553.5913]], dtype=float32), array([[2554.5024, 2564.26  ]], dtype=float32), array([[2565.1858, 2574.4084]], dtype=float32), array([[2575.739, 2584.51 ]], dtype=float32), array([[2586.0688, 2594.4185]], dtype=float32), array([[2595.7542, 2603.6733]], dtype=float32), array([[2604.827 , 2612.3147]], dtype=float32), array([[2613.2612, 2620.3218]], dtype=float32), array([[2621.0457, 2627.686 ]], dtype=float32), array([[2628.195 , 2634.4285]], dtype=float32), array([[2634.7322, 2640.577 ]], dtype=float32), array([[2640.676, 2646.153]], dtype=float32)]
# [2509.8472, 2519.2393, 2531.17, 2543.2441, 2554.5024, 2565.1858, 2575.739, 2586.0688, 2595.7542, 2604.827, 2613.2612, 2621.0457, 2628.195, 2634.7322, 2640.676]
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 51/51 [==============================] - 4s 25ms/step - loss: 0.3360 - mae: 0.3315 - rmse: 0.3360 - val_loss: 0.0118 - val_mae: 0.0099 - val_rmse: 0.0115
# Epoch 2/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1233 - mae: 0.1157 - rmse: 0.1233 - val_loss: 0.0203 - val_mae: 0.0183 - val_rmse: 0.0203
# Epoch 3/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1658 - mae: 0.1626 - rmse: 0.1658 - val_loss: 0.0829 - val_mae: 0.0812 - val_rmse: 0.0832
# Epoch 4/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1123 - mae: 0.1080 - rmse: 0.1123 - val_loss: 0.0834 - val_mae: 0.0820 - val_rmse: 0.0837
# Epoch 5/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1144 - mae: 0.1107 - rmse: 0.1144 - val_loss: 0.0728 - val_mae: 0.0714 - val_rmse: 0.0730
#
# Epoch 00005: val_loss improved from inf to 0.07276, saving model to my_model_5_0.073.h5
# Epoch 6/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1217 - mae: 0.1181 - rmse: 0.1217 - val_loss: 0.0676 - val_mae: 0.0661 - val_rmse: 0.0679
# Epoch 7/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1289 - mae: 0.1255 - rmse: 0.1289 - val_loss: 0.0610 - val_mae: 0.0597 - val_rmse: 0.0613
# Epoch 8/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1316 - mae: 0.1286 - rmse: 0.1316 - val_loss: 0.0609 - val_mae: 0.0597 - val_rmse: 0.0611
# Epoch 9/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1285 - mae: 0.1254 - rmse: 0.1285 - val_loss: 0.0594 - val_mae: 0.0584 - val_rmse: 0.0596
# Epoch 10/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1277 - mae: 0.1248 - rmse: 0.1277 - val_loss: 0.0593 - val_mae: 0.0584 - val_rmse: 0.0595
#
# Epoch 00010: val_loss improved from 0.07276 to 0.05925, saving model to my_model_10_0.059.h5
# Epoch 11/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1240 - mae: 0.1210 - rmse: 0.1240 - val_loss: 0.0569 - val_mae: 0.0559 - val_rmse: 0.0571
# Epoch 12/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1242 - mae: 0.1212 - rmse: 0.1242 - val_loss: 0.0567 - val_mae: 0.0560 - val_rmse: 0.0570
# Epoch 13/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1202 - mae: 0.1173 - rmse: 0.1202 - val_loss: 0.0550 - val_mae: 0.0543 - val_rmse: 0.0553
# Epoch 14/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1191 - mae: 0.1161 - rmse: 0.1191 - val_loss: 0.0534 - val_mae: 0.0527 - val_rmse: 0.0537
# Epoch 15/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1169 - mae: 0.1140 - rmse: 0.1169 - val_loss: 0.0517 - val_mae: 0.0511 - val_rmse: 0.0520
#
# Epoch 00015: val_loss improved from 0.05925 to 0.05168, saving model to my_model_15_0.052.h5
# Epoch 16/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1150 - mae: 0.1121 - rmse: 0.1150 - val_loss: 0.0502 - val_mae: 0.0497 - val_rmse: 0.0505
# Epoch 17/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1105 - mae: 0.1075 - rmse: 0.1105 - val_loss: 0.0462 - val_mae: 0.0457 - val_rmse: 0.0465
# Epoch 18/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1104 - mae: 0.1076 - rmse: 0.1104 - val_loss: 0.0426 - val_mae: 0.0421 - val_rmse: 0.0429
# Epoch 19/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1067 - mae: 0.1038 - rmse: 0.1067 - val_loss: 0.0430 - val_mae: 0.0425 - val_rmse: 0.0432
# Epoch 20/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1035 - mae: 0.1004 - rmse: 0.1034 - val_loss: 0.0428 - val_mae: 0.0423 - val_rmse: 0.0430
#
# Epoch 00020: val_loss improved from 0.05168 to 0.04275, saving model to my_model_20_0.043.h5
# Epoch 21/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1000 - mae: 0.0969 - rmse: 0.1000 - val_loss: 0.0421 - val_mae: 0.0417 - val_rmse: 0.0424
# Epoch 22/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0977 - mae: 0.0946 - rmse: 0.0977 - val_loss: 0.0402 - val_mae: 0.0398 - val_rmse: 0.0405
# Epoch 23/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0959 - mae: 0.0928 - rmse: 0.0959 - val_loss: 0.0387 - val_mae: 0.0382 - val_rmse: 0.0390
# Epoch 24/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0942 - mae: 0.0911 - rmse: 0.0942 - val_loss: 0.0370 - val_mae: 0.0365 - val_rmse: 0.0373
# Epoch 25/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0921 - mae: 0.0890 - rmse: 0.0921 - val_loss: 0.0358 - val_mae: 0.0353 - val_rmse: 0.0361
#
# Epoch 00025: val_loss improved from 0.04275 to 0.03583, saving model to my_model_25_0.036.h5
# Epoch 26/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0902 - mae: 0.0870 - rmse: 0.0902 - val_loss: 0.0341 - val_mae: 0.0336 - val_rmse: 0.0344
# Epoch 27/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0879 - mae: 0.0848 - rmse: 0.0879 - val_loss: 0.0328 - val_mae: 0.0322 - val_rmse: 0.0331
# Epoch 28/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0861 - mae: 0.0829 - rmse: 0.0861 - val_loss: 0.0304 - val_mae: 0.0298 - val_rmse: 0.0307
# Epoch 29/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0841 - mae: 0.0809 - rmse: 0.0841 - val_loss: 0.0293 - val_mae: 0.0287 - val_rmse: 0.0296
# Epoch 30/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0816 - mae: 0.0783 - rmse: 0.0816 - val_loss: 0.0273 - val_mae: 0.0266 - val_rmse: 0.0276
#
# Epoch 00030: val_loss improved from 0.03583 to 0.02725, saving model to my_model_30_0.027.h5
# Epoch 31/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0796 - mae: 0.0762 - rmse: 0.0796 - val_loss: 0.0257 - val_mae: 0.0251 - val_rmse: 0.0260
# Epoch 32/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0772 - mae: 0.0738 - rmse: 0.0772 - val_loss: 0.0257 - val_mae: 0.0250 - val_rmse: 0.0260
# Epoch 33/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0747 - mae: 0.0711 - rmse: 0.0747 - val_loss: 0.0249 - val_mae: 0.0242 - val_rmse: 0.0252
# Epoch 34/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0728 - mae: 0.0691 - rmse: 0.0728 - val_loss: 0.0259 - val_mae: 0.0252 - val_rmse: 0.0262
# Epoch 35/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0703 - mae: 0.0666 - rmse: 0.0703 - val_loss: 0.0239 - val_mae: 0.0231 - val_rmse: 0.0242
#
# Epoch 00035: val_loss improved from 0.02725 to 0.02385, saving model to my_model_35_0.024.h5
# Epoch 36/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0691 - mae: 0.0653 - rmse: 0.0691 - val_loss: 0.0231 - val_mae: 0.0223 - val_rmse: 0.0234
# Epoch 37/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0672 - mae: 0.0634 - rmse: 0.0672 - val_loss: 0.0215 - val_mae: 0.0207 - val_rmse: 0.0218
# Epoch 38/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0657 - mae: 0.0620 - rmse: 0.0657 - val_loss: 0.0205 - val_mae: 0.0196 - val_rmse: 0.0208
# Epoch 39/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0637 - mae: 0.0601 - rmse: 0.0637 - val_loss: 0.0195 - val_mae: 0.0185 - val_rmse: 0.0197
# Epoch 40/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0627 - mae: 0.0590 - rmse: 0.0627 - val_loss: 0.0177 - val_mae: 0.0167 - val_rmse: 0.0180
#
# Epoch 00040: val_loss improved from 0.02385 to 0.01773, saving model to my_model_40_0.018.h5
# Epoch 41/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0606 - mae: 0.0570 - rmse: 0.0606 - val_loss: 0.0186 - val_mae: 0.0176 - val_rmse: 0.0188
# Epoch 42/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0597 - mae: 0.0561 - rmse: 0.0597 - val_loss: 0.0158 - val_mae: 0.0148 - val_rmse: 0.0160
# Epoch 43/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0567 - mae: 0.0531 - rmse: 0.0567 - val_loss: 0.0097 - val_mae: 0.0087 - val_rmse: 0.0099
# Epoch 44/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0622 - mae: 0.0586 - rmse: 0.0622 - val_loss: 0.0105 - val_mae: 0.0095 - val_rmse: 0.0107
# Epoch 45/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0534 - mae: 0.0497 - rmse: 0.0533 - val_loss: 0.0159 - val_mae: 0.0150 - val_rmse: 0.0162
#
# Epoch 00045: val_loss improved from 0.01773 to 0.01591, saving model to my_model_45_0.016.h5
# Epoch 46/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0543 - mae: 0.0509 - rmse: 0.0543 - val_loss: 0.0063 - val_mae: 0.0050 - val_rmse: 0.0062
# Epoch 47/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0584 - mae: 0.0549 - rmse: 0.0584 - val_loss: 0.0062 - val_mae: 0.0049 - val_rmse: 0.0060
# Epoch 48/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0564 - mae: 0.0528 - rmse: 0.0564 - val_loss: 0.0059 - val_mae: 0.0046 - val_rmse: 0.0059
# Epoch 49/50
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0541 - mae: 0.0506 - rmse: 0.0541 - val_loss: 0.0059 - val_mae: 0.0048 - val_rmse: 0.0059
# Epoch 50/50
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0530 - mae: 0.0495 - rmse: 0.0530 - val_loss: 0.0065 - val_mae: 0.0052 - val_rmse: 0.0063
#
# Epoch 00050: val_loss improved from 0.01591 to 0.00646, saving model to my_model_50_0.006.h5
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0173 - mae: 0.0130 - rmse: 0.0172
# Epoch 1/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0323 - mae: 0.0299 - rmse: 0.0321 - val_loss: 0.0146 - val_mae: 0.0125 - val_rmse: 0.0142
# Epoch 2/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0379 - mae: 0.0353 - rmse: 0.0377 - val_loss: 0.0174 - val_mae: 0.0148 - val_rmse: 0.0168
# Epoch 3/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0352 - mae: 0.0327 - rmse: 0.0350 - val_loss: 0.0146 - val_mae: 0.0119 - val_rmse: 0.0149
# Epoch 4/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0357 - mae: 0.0328 - rmse: 0.0355 - val_loss: 0.0232 - val_mae: 0.0201 - val_rmse: 0.0238
# Epoch 5/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0353 - mae: 0.0316 - rmse: 0.0352 - val_loss: 0.0188 - val_mae: 0.0156 - val_rmse: 0.0196
#
# Epoch 00005: val_loss did not improve from 0.00646
# Epoch 6/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0328 - mae: 0.0291 - rmse: 0.0326 - val_loss: 0.0152 - val_mae: 0.0124 - val_rmse: 0.0161
# Epoch 7/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0327 - mae: 0.0292 - rmse: 0.0325 - val_loss: 0.0133 - val_mae: 0.0106 - val_rmse: 0.0138
# Epoch 8/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0356 - mae: 0.0327 - rmse: 0.0354 - val_loss: 0.0119 - val_mae: 0.0096 - val_rmse: 0.0125
# Epoch 9/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0357 - mae: 0.0332 - rmse: 0.0355 - val_loss: 0.0127 - val_mae: 0.0103 - val_rmse: 0.0130
# Epoch 10/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0355 - mae: 0.0330 - rmse: 0.0353 - val_loss: 0.0113 - val_mae: 0.0091 - val_rmse: 0.0118
#
# Epoch 00010: val_loss did not improve from 0.00646
# Epoch 11/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0348 - mae: 0.0327 - rmse: 0.0346 - val_loss: 0.0126 - val_mae: 0.0103 - val_rmse: 0.0129
# Epoch 12/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0335 - mae: 0.0311 - rmse: 0.0333 - val_loss: 0.0112 - val_mae: 0.0091 - val_rmse: 0.0117
# Epoch 13/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0342 - mae: 0.0322 - rmse: 0.0340 - val_loss: 0.0151 - val_mae: 0.0132 - val_rmse: 0.0149
# Epoch 14/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0356 - mae: 0.0333 - rmse: 0.0354 - val_loss: 0.0129 - val_mae: 0.0111 - val_rmse: 0.0129
# Epoch 15/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0324 - mae: 0.0304 - rmse: 0.0322 - val_loss: 0.0137 - val_mae: 0.0121 - val_rmse: 0.0138
#
# Epoch 00015: val_loss did not improve from 0.00646
# Epoch 16/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0359 - mae: 0.0338 - rmse: 0.0358 - val_loss: 0.0289 - val_mae: 0.0278 - val_rmse: 0.0274
# Epoch 17/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0345 - mae: 0.0324 - rmse: 0.0343 - val_loss: 0.0134 - val_mae: 0.0117 - val_rmse: 0.0135
# Epoch 18/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0339 - mae: 0.0317 - rmse: 0.0337 - val_loss: 0.0139 - val_mae: 0.0122 - val_rmse: 0.0137
# Epoch 19/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0333 - mae: 0.0313 - rmse: 0.0332 - val_loss: 0.0127 - val_mae: 0.0108 - val_rmse: 0.0129
# Epoch 20/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0328 - mae: 0.0307 - rmse: 0.0327 - val_loss: 0.0115 - val_mae: 0.0098 - val_rmse: 0.0118
#
# Epoch 00020: val_loss did not improve from 0.00646
# Epoch 21/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0313 - mae: 0.0293 - rmse: 0.0312 - val_loss: 0.0138 - val_mae: 0.0122 - val_rmse: 0.0137
# Epoch 22/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0326 - mae: 0.0305 - rmse: 0.0324 - val_loss: 0.0130 - val_mae: 0.0114 - val_rmse: 0.0130
# Epoch 23/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0314 - mae: 0.0293 - rmse: 0.0312 - val_loss: 0.0107 - val_mae: 0.0089 - val_rmse: 0.0115
# Epoch 24/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0297 - mae: 0.0277 - rmse: 0.0296 - val_loss: 0.0111 - val_mae: 0.0092 - val_rmse: 0.0119
# Epoch 25/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0305 - mae: 0.0285 - rmse: 0.0303 - val_loss: 0.0153 - val_mae: 0.0136 - val_rmse: 0.0151
#
# Epoch 00025: val_loss did not improve from 0.00646
# Epoch 26/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0336 - mae: 0.0316 - rmse: 0.0335 - val_loss: 0.0109 - val_mae: 0.0095 - val_rmse: 0.0116
# Epoch 27/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0242 - mae: 0.0220 - rmse: 0.0241 - val_loss: 0.0108 - val_mae: 0.0094 - val_rmse: 0.0114
# Epoch 28/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0323 - mae: 0.0306 - rmse: 0.0321 - val_loss: 0.0132 - val_mae: 0.0120 - val_rmse: 0.0135
# Epoch 29/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0299 - mae: 0.0279 - rmse: 0.0298 - val_loss: 0.0105 - val_mae: 0.0093 - val_rmse: 0.0114
# Epoch 30/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0251 - mae: 0.0229 - rmse: 0.0250 - val_loss: 0.0105 - val_mae: 0.0089 - val_rmse: 0.0113
#
# Epoch 00030: val_loss did not improve from 0.00646
# Epoch 31/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0329 - mae: 0.0312 - rmse: 0.0328 - val_loss: 0.0108 - val_mae: 0.0099 - val_rmse: 0.0116
# Epoch 32/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0321 - mae: 0.0301 - rmse: 0.0320 - val_loss: 0.0184 - val_mae: 0.0169 - val_rmse: 0.0180
# Epoch 33/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0306 - mae: 0.0284 - rmse: 0.0305 - val_loss: 0.0158 - val_mae: 0.0143 - val_rmse: 0.0158
# Epoch 34/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0274 - mae: 0.0250 - rmse: 0.0273 - val_loss: 0.0115 - val_mae: 0.0100 - val_rmse: 0.0121
# Epoch 35/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0306 - mae: 0.0283 - rmse: 0.0305 - val_loss: 0.0172 - val_mae: 0.0141 - val_rmse: 0.0177
#
# Epoch 00035: val_loss did not improve from 0.00646
# Epoch 36/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0289 - mae: 0.0260 - rmse: 0.0288 - val_loss: 0.0107 - val_mae: 0.0087 - val_rmse: 0.0121
# Epoch 37/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0267 - mae: 0.0243 - rmse: 0.0266 - val_loss: 0.0118 - val_mae: 0.0106 - val_rmse: 0.0122
# Epoch 38/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0273 - mae: 0.0250 - rmse: 0.0272 - val_loss: 0.0103 - val_mae: 0.0089 - val_rmse: 0.0110
# Epoch 39/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0265 - mae: 0.0244 - rmse: 0.0264 - val_loss: 0.0113 - val_mae: 0.0093 - val_rmse: 0.0120
# Epoch 40/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0291 - mae: 0.0270 - rmse: 0.0291 - val_loss: 0.0135 - val_mae: 0.0121 - val_rmse: 0.0138
#
# Epoch 00040: val_loss did not improve from 0.00646
# Epoch 41/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0281 - mae: 0.0260 - rmse: 0.0280 - val_loss: 0.0096 - val_mae: 0.0083 - val_rmse: 0.0104
# Epoch 42/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0275 - mae: 0.0254 - rmse: 0.0274 - val_loss: 0.0101 - val_mae: 0.0091 - val_rmse: 0.0108
# Epoch 43/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0263 - mae: 0.0244 - rmse: 0.0262 - val_loss: 0.0102 - val_mae: 0.0091 - val_rmse: 0.0108
# Epoch 44/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0277 - mae: 0.0259 - rmse: 0.0276 - val_loss: 0.0114 - val_mae: 0.0101 - val_rmse: 0.0116
# Epoch 45/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0262 - mae: 0.0243 - rmse: 0.0261 - val_loss: 0.0136 - val_mae: 0.0121 - val_rmse: 0.0135
#
# Epoch 00045: val_loss did not improve from 0.00646
# Epoch 46/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0260 - mae: 0.0241 - rmse: 0.0260 - val_loss: 0.0141 - val_mae: 0.0127 - val_rmse: 0.0138
# Epoch 47/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0262 - mae: 0.0242 - rmse: 0.0261 - val_loss: 0.0152 - val_mae: 0.0138 - val_rmse: 0.0146
# Epoch 48/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0256 - mae: 0.0236 - rmse: 0.0255 - val_loss: 0.0157 - val_mae: 0.0144 - val_rmse: 0.0150
# Epoch 49/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0258 - mae: 0.0239 - rmse: 0.0257 - val_loss: 0.0185 - val_mae: 0.0171 - val_rmse: 0.0175
# Epoch 50/50
# 102/102 [==============================] - 1s 9ms/step - loss: 0.0268 - mae: 0.0248 - rmse: 0.0267 - val_loss: 0.0136 - val_mae: 0.0120 - val_rmse: 0.0132
#
# Epoch 00050: val_loss did not improve from 0.00646
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1344 - mae: 0.1307 - rmse: 0.1372
# Epoch 1/50
# 152/152 [==============================] - 3s 8ms/step - loss: 0.0217 - mae: 0.0198 - rmse: 0.0217 - val_loss: 0.0496 - val_mae: 0.0455 - val_rmse: 0.0493
# Epoch 2/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0170 - mae: 0.0151 - rmse: 0.0170 - val_loss: 0.0462 - val_mae: 0.0424 - val_rmse: 0.0459
# Epoch 3/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0265 - mae: 0.0248 - rmse: 0.0265 - val_loss: 0.0373 - val_mae: 0.0331 - val_rmse: 0.0372
# Epoch 4/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0211 - mae: 0.0193 - rmse: 0.0211 - val_loss: 0.0541 - val_mae: 0.0501 - val_rmse: 0.0537
# Epoch 5/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0203 - mae: 0.0184 - rmse: 0.0203 - val_loss: 0.0465 - val_mae: 0.0427 - val_rmse: 0.0462
#
# Epoch 00005: val_loss did not improve from 0.00646
# Epoch 6/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0177 - mae: 0.0158 - rmse: 0.0177 - val_loss: 0.0552 - val_mae: 0.0513 - val_rmse: 0.0548
# Epoch 7/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.0149 - mae: 0.0129 - rmse: 0.0149 - val_loss: 0.0561 - val_mae: 0.0521 - val_rmse: 0.0557
# Epoch 8/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0171 - mae: 0.0152 - rmse: 0.0171 - val_loss: 0.0564 - val_mae: 0.0524 - val_rmse: 0.0560
# Epoch 9/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0162 - mae: 0.0144 - rmse: 0.0162 - val_loss: 0.0569 - val_mae: 0.0528 - val_rmse: 0.0565
# Epoch 10/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0167 - mae: 0.0148 - rmse: 0.0167 - val_loss: 0.0578 - val_mae: 0.0536 - val_rmse: 0.0574
#
# Epoch 00010: val_loss did not improve from 0.00646
# Epoch 11/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0205 - mae: 0.0183 - rmse: 0.0205 - val_loss: 0.0591 - val_mae: 0.0550 - val_rmse: 0.0587
# Epoch 12/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0195 - mae: 0.0173 - rmse: 0.0195 - val_loss: 0.0606 - val_mae: 0.0564 - val_rmse: 0.0602
# Epoch 13/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0183 - mae: 0.0163 - rmse: 0.0183 - val_loss: 0.0637 - val_mae: 0.0594 - val_rmse: 0.0633
# Epoch 14/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0202 - mae: 0.0182 - rmse: 0.0202 - val_loss: 0.0626 - val_mae: 0.0580 - val_rmse: 0.0621
# Epoch 15/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0202 - mae: 0.0184 - rmse: 0.0202 - val_loss: 0.0499 - val_mae: 0.0452 - val_rmse: 0.0498
#
# Epoch 00015: val_loss did not improve from 0.00646
# Epoch 16/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0217 - mae: 0.0197 - rmse: 0.0217 - val_loss: 0.0511 - val_mae: 0.0473 - val_rmse: 0.0507
# Epoch 17/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0219 - mae: 0.0201 - rmse: 0.0219 - val_loss: 0.0441 - val_mae: 0.0400 - val_rmse: 0.0440
# Epoch 18/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0151 - mae: 0.0131 - rmse: 0.0151 - val_loss: 0.0456 - val_mae: 0.0415 - val_rmse: 0.0454
# Epoch 19/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0175 - mae: 0.0156 - rmse: 0.0175 - val_loss: 0.0504 - val_mae: 0.0464 - val_rmse: 0.0501
# Epoch 20/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0222 - mae: 0.0204 - rmse: 0.0222 - val_loss: 0.0529 - val_mae: 0.0488 - val_rmse: 0.0526
#
# Epoch 00020: val_loss did not improve from 0.00646
# Epoch 21/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0189 - mae: 0.0171 - rmse: 0.0189 - val_loss: 0.0563 - val_mae: 0.0521 - val_rmse: 0.0559
# Epoch 22/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0223 - mae: 0.0205 - rmse: 0.0223 - val_loss: 0.0588 - val_mae: 0.0544 - val_rmse: 0.0584
# Epoch 23/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0215 - mae: 0.0196 - rmse: 0.0215 - val_loss: 0.0563 - val_mae: 0.0520 - val_rmse: 0.0559
# Epoch 24/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0222 - mae: 0.0204 - rmse: 0.0222 - val_loss: 0.0579 - val_mae: 0.0535 - val_rmse: 0.0574
# Epoch 25/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0222 - mae: 0.0203 - rmse: 0.0222 - val_loss: 0.0593 - val_mae: 0.0549 - val_rmse: 0.0589
#
# Epoch 00025: val_loss did not improve from 0.00646
# Epoch 26/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0189 - mae: 0.0171 - rmse: 0.0189 - val_loss: 0.0622 - val_mae: 0.0577 - val_rmse: 0.0617
# Epoch 27/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0224 - mae: 0.0206 - rmse: 0.0224 - val_loss: 0.0668 - val_mae: 0.0620 - val_rmse: 0.0664
# Epoch 28/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0223 - mae: 0.0204 - rmse: 0.0223 - val_loss: 0.0715 - val_mae: 0.0665 - val_rmse: 0.0711
# Epoch 29/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.0223 - mae: 0.0204 - rmse: 0.0223 - val_loss: 0.0744 - val_mae: 0.0693 - val_rmse: 0.0739
# Epoch 30/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.0225 - mae: 0.0207 - rmse: 0.0225 - val_loss: 0.0780 - val_mae: 0.0731 - val_rmse: 0.0776
#
# Epoch 00030: val_loss did not improve from 0.00646
# Epoch 31/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0217 - mae: 0.0200 - rmse: 0.0217 - val_loss: 0.0852 - val_mae: 0.0803 - val_rmse: 0.0847
# Epoch 32/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0220 - mae: 0.0202 - rmse: 0.0220 - val_loss: 0.0859 - val_mae: 0.0810 - val_rmse: 0.0854
# Epoch 33/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0210 - mae: 0.0192 - rmse: 0.0210 - val_loss: 0.0966 - val_mae: 0.0915 - val_rmse: 0.0961
# Epoch 34/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0218 - mae: 0.0200 - rmse: 0.0218 - val_loss: 0.1015 - val_mae: 0.0963 - val_rmse: 0.1011
# Epoch 35/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0214 - mae: 0.0196 - rmse: 0.0214 - val_loss: 0.1079 - val_mae: 0.1024 - val_rmse: 0.1074
#
# Epoch 00035: val_loss did not improve from 0.00646
# Epoch 36/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.0214 - mae: 0.0196 - rmse: 0.0214 - val_loss: 0.1138 - val_mae: 0.1082 - val_rmse: 0.1133
# Epoch 37/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0203 - mae: 0.0185 - rmse: 0.0203 - val_loss: 0.1154 - val_mae: 0.1097 - val_rmse: 0.1149
# Epoch 38/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0181 - mae: 0.0163 - rmse: 0.0181 - val_loss: 0.1213 - val_mae: 0.1155 - val_rmse: 0.1207
# Epoch 39/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0221 - mae: 0.0202 - rmse: 0.0221 - val_loss: 0.1155 - val_mae: 0.1100 - val_rmse: 0.1150
# Epoch 40/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0220 - mae: 0.0201 - rmse: 0.0220 - val_loss: 0.1195 - val_mae: 0.1138 - val_rmse: 0.1190
#
# Epoch 00040: val_loss did not improve from 0.00646
# Epoch 41/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0243 - mae: 0.0224 - rmse: 0.0243 - val_loss: 0.1195 - val_mae: 0.1138 - val_rmse: 0.1190
# Epoch 42/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0234 - mae: 0.0215 - rmse: 0.0234 - val_loss: 0.1224 - val_mae: 0.1166 - val_rmse: 0.1219
# Epoch 43/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0236 - mae: 0.0218 - rmse: 0.0236 - val_loss: 0.1230 - val_mae: 0.1173 - val_rmse: 0.1225
# Epoch 44/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0226 - mae: 0.0208 - rmse: 0.0226 - val_loss: 0.1252 - val_mae: 0.1194 - val_rmse: 0.1247
# Epoch 45/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0227 - mae: 0.0209 - rmse: 0.0227 - val_loss: 0.1263 - val_mae: 0.1206 - val_rmse: 0.1259
#
# Epoch 00045: val_loss did not improve from 0.00646
# Epoch 46/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0219 - mae: 0.0200 - rmse: 0.0219 - val_loss: 0.1207 - val_mae: 0.1150 - val_rmse: 0.1202
# Epoch 47/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0220 - mae: 0.0201 - rmse: 0.0220 - val_loss: 0.1141 - val_mae: 0.1085 - val_rmse: 0.1136
# Epoch 48/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.0216 - mae: 0.0198 - rmse: 0.0216 - val_loss: 0.1019 - val_mae: 0.0964 - val_rmse: 0.1014
# Epoch 49/50
# 152/152 [==============================] - 1s 7ms/step - loss: 0.0217 - mae: 0.0199 - rmse: 0.0217 - val_loss: 0.0935 - val_mae: 0.0881 - val_rmse: 0.0930
# Epoch 50/50
# 152/152 [==============================] - 1s 8ms/step - loss: 0.0218 - mae: 0.0199 - rmse: 0.0218 - val_loss: 0.0879 - val_mae: 0.0824 - val_rmse: 0.0874
#
# Epoch 00050: val_loss did not improve from 0.00646
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1494 - mae: 0.1359 - rmse: 0.1474
# [array([[2488.347 , 2486.2598]], dtype=float32), array([[2495.3  , 2493.228]], dtype=float32), array([[2507.973 , 2505.9302]], dtype=float32), array([[2520.3906, 2518.3926]], dtype=float32), array([[2532.3706, 2530.4392]], dtype=float32), array([[2543.381 , 2541.5247]], dtype=float32), array([[2553.98  , 2552.2007]], dtype=float32), array([[2564.697, 2562.994]], dtype=float32), array([[2575.404 , 2573.7766]], dtype=float32), array([[2586.127 , 2584.5774]], dtype=float32), array([[2596.7366, 2595.269 ]], dtype=float32), array([[2607.0999, 2605.718 ]], dtype=float32), array([[2617.081 , 2615.7876]], dtype=float32), array([[2626.5942, 2625.3918]], dtype=float32), array([[2635.573 , 2634.4624]], dtype=float32)]
# [2488.347, 2495.3, 2507.973, 2520.3906, 2532.3706, 2543.381, 2553.98, 2564.697, 2575.404, 2586.127, 2596.7366, 2607.0999, 2617.081, 2626.5942, 2635.573]
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 51/51 [==============================] - 4s 26ms/step - loss: 0.2771 - mae: 0.2722 - rmse: 0.2771 - val_loss: 0.0140 - val_mae: 0.0126 - val_rmse: 0.0136
# Epoch 2/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0961 - mae: 0.0912 - rmse: 0.0961 - val_loss: 0.0203 - val_mae: 0.0193 - val_rmse: 0.0199
# Epoch 3/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1563 - mae: 0.1512 - rmse: 0.1563 - val_loss: 0.0728 - val_mae: 0.0626 - val_rmse: 0.0731
# Epoch 4/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1332 - mae: 0.1261 - rmse: 0.1332 - val_loss: 0.0800 - val_mae: 0.0791 - val_rmse: 0.0803
# Epoch 5/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1207 - mae: 0.1168 - rmse: 0.1207 - val_loss: 0.0748 - val_mae: 0.0744 - val_rmse: 0.0751
#
# Epoch 00005: val_loss improved from inf to 0.07479, saving model to my_model_5_0.075.h5
# Epoch 6/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1227 - mae: 0.1193 - rmse: 0.1227 - val_loss: 0.0741 - val_mae: 0.0739 - val_rmse: 0.0744
# Epoch 7/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1214 - mae: 0.1182 - rmse: 0.1214 - val_loss: 0.0705 - val_mae: 0.0702 - val_rmse: 0.0708
# Epoch 8/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1281 - mae: 0.1250 - rmse: 0.1280 - val_loss: 0.0673 - val_mae: 0.0669 - val_rmse: 0.0676
# Epoch 9/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1260 - mae: 0.1228 - rmse: 0.1260 - val_loss: 0.0657 - val_mae: 0.0651 - val_rmse: 0.0660
# Epoch 10/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1260 - mae: 0.1226 - rmse: 0.1259 - val_loss: 0.0636 - val_mae: 0.0629 - val_rmse: 0.0638
#
# Epoch 00010: val_loss improved from 0.07479 to 0.06356, saving model to my_model_10_0.064.h5
# Epoch 11/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1265 - mae: 0.1233 - rmse: 0.1265 - val_loss: 0.0585 - val_mae: 0.0580 - val_rmse: 0.0588
# Epoch 12/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1274 - mae: 0.1244 - rmse: 0.1274 - val_loss: 0.0555 - val_mae: 0.0551 - val_rmse: 0.0558
# Epoch 13/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1278 - mae: 0.1249 - rmse: 0.1278 - val_loss: 0.0523 - val_mae: 0.0519 - val_rmse: 0.0526
# Epoch 14/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1272 - mae: 0.1244 - rmse: 0.1272 - val_loss: 0.0556 - val_mae: 0.0553 - val_rmse: 0.0559
# Epoch 15/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1218 - mae: 0.1189 - rmse: 0.1218 - val_loss: 0.0566 - val_mae: 0.0562 - val_rmse: 0.0569
#
# Epoch 00015: val_loss improved from 0.06356 to 0.05658, saving model to my_model_15_0.057.h5
# Epoch 16/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1190 - mae: 0.1161 - rmse: 0.1190 - val_loss: 0.0556 - val_mae: 0.0553 - val_rmse: 0.0559
# Epoch 17/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1164 - mae: 0.1135 - rmse: 0.1164 - val_loss: 0.0540 - val_mae: 0.0536 - val_rmse: 0.0543
# Epoch 18/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.1145 - mae: 0.1116 - rmse: 0.1145 - val_loss: 0.0517 - val_mae: 0.0514 - val_rmse: 0.0520
# Epoch 19/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1106 - mae: 0.1076 - rmse: 0.1106 - val_loss: 0.0471 - val_mae: 0.0467 - val_rmse: 0.0474
# Epoch 20/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1123 - mae: 0.1094 - rmse: 0.1123 - val_loss: 0.0437 - val_mae: 0.0432 - val_rmse: 0.0440
#
# Epoch 00020: val_loss improved from 0.05658 to 0.04370, saving model to my_model_20_0.044.h5
# Epoch 21/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1068 - mae: 0.1036 - rmse: 0.1068 - val_loss: 0.0429 - val_mae: 0.0423 - val_rmse: 0.0432
# Epoch 22/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1050 - mae: 0.1018 - rmse: 0.1050 - val_loss: 0.0406 - val_mae: 0.0399 - val_rmse: 0.0409
# Epoch 23/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.1021 - mae: 0.0988 - rmse: 0.1021 - val_loss: 0.0407 - val_mae: 0.0402 - val_rmse: 0.0410
# Epoch 24/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0990 - mae: 0.0957 - rmse: 0.0990 - val_loss: 0.0390 - val_mae: 0.0386 - val_rmse: 0.0394
# Epoch 25/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0969 - mae: 0.0937 - rmse: 0.0969 - val_loss: 0.0369 - val_mae: 0.0363 - val_rmse: 0.0372
#
# Epoch 00025: val_loss improved from 0.04370 to 0.03688, saving model to my_model_25_0.037.h5
# Epoch 26/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0953 - mae: 0.0920 - rmse: 0.0953 - val_loss: 0.0348 - val_mae: 0.0342 - val_rmse: 0.0351
# Epoch 27/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0935 - mae: 0.0902 - rmse: 0.0935 - val_loss: 0.0329 - val_mae: 0.0323 - val_rmse: 0.0333
# Epoch 28/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0916 - mae: 0.0883 - rmse: 0.0916 - val_loss: 0.0314 - val_mae: 0.0308 - val_rmse: 0.0317
# Epoch 29/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0896 - mae: 0.0864 - rmse: 0.0896 - val_loss: 0.0298 - val_mae: 0.0291 - val_rmse: 0.0301
# Epoch 30/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0873 - mae: 0.0840 - rmse: 0.0873 - val_loss: 0.0294 - val_mae: 0.0285 - val_rmse: 0.0297
#
# Epoch 00030: val_loss improved from 0.03688 to 0.02937, saving model to my_model_30_0.029.h5
# Epoch 31/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0847 - mae: 0.0813 - rmse: 0.0847 - val_loss: 0.0278 - val_mae: 0.0268 - val_rmse: 0.0281
# Epoch 32/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0820 - mae: 0.0785 - rmse: 0.0820 - val_loss: 0.0287 - val_mae: 0.0279 - val_rmse: 0.0291
# Epoch 33/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0799 - mae: 0.0763 - rmse: 0.0799 - val_loss: 0.0262 - val_mae: 0.0255 - val_rmse: 0.0265
# Epoch 34/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0782 - mae: 0.0745 - rmse: 0.0782 - val_loss: 0.0283 - val_mae: 0.0276 - val_rmse: 0.0287
# Epoch 35/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0755 - mae: 0.0717 - rmse: 0.0755 - val_loss: 0.0252 - val_mae: 0.0241 - val_rmse: 0.0255
#
# Epoch 00035: val_loss improved from 0.02937 to 0.02517, saving model to my_model_35_0.025.h5
# Epoch 36/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0741 - mae: 0.0700 - rmse: 0.0741 - val_loss: 0.0243 - val_mae: 0.0231 - val_rmse: 0.0246
# Epoch 37/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0729 - mae: 0.0690 - rmse: 0.0729 - val_loss: 0.0216 - val_mae: 0.0205 - val_rmse: 0.0219
# Epoch 38/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0719 - mae: 0.0680 - rmse: 0.0719 - val_loss: 0.0229 - val_mae: 0.0221 - val_rmse: 0.0232
# Epoch 39/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0698 - mae: 0.0659 - rmse: 0.0698 - val_loss: 0.0223 - val_mae: 0.0211 - val_rmse: 0.0226
# Epoch 40/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0675 - mae: 0.0634 - rmse: 0.0675 - val_loss: 0.0207 - val_mae: 0.0186 - val_rmse: 0.0210
#
# Epoch 00040: val_loss improved from 0.02517 to 0.02073, saving model to my_model_40_0.021.h5
# Epoch 41/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0656 - mae: 0.0613 - rmse: 0.0656 - val_loss: 0.0177 - val_mae: 0.0154 - val_rmse: 0.0179
# Epoch 42/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0648 - mae: 0.0607 - rmse: 0.0648 - val_loss: 0.0157 - val_mae: 0.0139 - val_rmse: 0.0160
# Epoch 43/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0645 - mae: 0.0605 - rmse: 0.0645 - val_loss: 0.0162 - val_mae: 0.0152 - val_rmse: 0.0165
# Epoch 44/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0640 - mae: 0.0598 - rmse: 0.0640 - val_loss: 0.0177 - val_mae: 0.0152 - val_rmse: 0.0180
# Epoch 45/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0605 - mae: 0.0558 - rmse: 0.0605 - val_loss: 0.0142 - val_mae: 0.0115 - val_rmse: 0.0144
#
# Epoch 00045: val_loss improved from 0.02073 to 0.01422, saving model to my_model_45_0.014.h5
# Epoch 46/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0582 - mae: 0.0536 - rmse: 0.0582 - val_loss: 0.0110 - val_mae: 0.0090 - val_rmse: 0.0112
# Epoch 47/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0605 - mae: 0.0565 - rmse: 0.0605 - val_loss: 0.0063 - val_mae: 0.0053 - val_rmse: 0.0064
# Epoch 48/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0637 - mae: 0.0596 - rmse: 0.0637 - val_loss: 0.0085 - val_mae: 0.0070 - val_rmse: 0.0085
# Epoch 49/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0583 - mae: 0.0538 - rmse: 0.0583 - val_loss: 0.0091 - val_mae: 0.0075 - val_rmse: 0.0092
# Epoch 50/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0550 - mae: 0.0511 - rmse: 0.0550 - val_loss: 0.0090 - val_mae: 0.0078 - val_rmse: 0.0092
#
# Epoch 00050: val_loss improved from 0.01422 to 0.00903, saving model to my_model_50_0.009.h5
# Epoch 51/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0556 - mae: 0.0520 - rmse: 0.0556 - val_loss: 0.0065 - val_mae: 0.0052 - val_rmse: 0.0064
# Epoch 52/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0564 - mae: 0.0525 - rmse: 0.0564 - val_loss: 0.0068 - val_mae: 0.0054 - val_rmse: 0.0067
# Epoch 53/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0549 - mae: 0.0511 - rmse: 0.0549 - val_loss: 0.0077 - val_mae: 0.0062 - val_rmse: 0.0075
# Epoch 54/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0538 - mae: 0.0501 - rmse: 0.0538 - val_loss: 0.0084 - val_mae: 0.0069 - val_rmse: 0.0081
# Epoch 55/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0551 - mae: 0.0514 - rmse: 0.0551 - val_loss: 0.0115 - val_mae: 0.0101 - val_rmse: 0.0111
#
# Epoch 00055: val_loss did not improve from 0.00903
# Epoch 56/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0522 - mae: 0.0485 - rmse: 0.0522 - val_loss: 0.0108 - val_mae: 0.0093 - val_rmse: 0.0105
# Epoch 57/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0558 - mae: 0.0521 - rmse: 0.0558 - val_loss: 0.0147 - val_mae: 0.0136 - val_rmse: 0.0144
# Epoch 58/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0498 - mae: 0.0461 - rmse: 0.0498 - val_loss: 0.0112 - val_mae: 0.0098 - val_rmse: 0.0109
# Epoch 59/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0609 - mae: 0.0574 - rmse: 0.0609 - val_loss: 0.0145 - val_mae: 0.0134 - val_rmse: 0.0142
# Epoch 60/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0478 - mae: 0.0440 - rmse: 0.0478 - val_loss: 0.0097 - val_mae: 0.0082 - val_rmse: 0.0095
#
# Epoch 00060: val_loss did not improve from 0.00903
# Epoch 61/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0591 - mae: 0.0557 - rmse: 0.0591 - val_loss: 0.0115 - val_mae: 0.0101 - val_rmse: 0.0112
# Epoch 62/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0473 - mae: 0.0438 - rmse: 0.0473 - val_loss: 0.0058 - val_mae: 0.0045 - val_rmse: 0.0057
# Epoch 63/100
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0565 - mae: 0.0529 - rmse: 0.0565 - val_loss: 0.0177 - val_mae: 0.0168 - val_rmse: 0.0174
# Epoch 64/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0516 - mae: 0.0481 - rmse: 0.0515 - val_loss: 0.0062 - val_mae: 0.0051 - val_rmse: 0.0062
# Epoch 65/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0495 - mae: 0.0459 - rmse: 0.0495 - val_loss: 0.0145 - val_mae: 0.0134 - val_rmse: 0.0142
#
# Epoch 00065: val_loss did not improve from 0.00903
# Epoch 66/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0509 - mae: 0.0473 - rmse: 0.0509 - val_loss: 0.0115 - val_mae: 0.0102 - val_rmse: 0.0113
# Epoch 67/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0481 - mae: 0.0444 - rmse: 0.0481 - val_loss: 0.0136 - val_mae: 0.0124 - val_rmse: 0.0133
# Epoch 68/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0497 - mae: 0.0460 - rmse: 0.0497 - val_loss: 0.0115 - val_mae: 0.0102 - val_rmse: 0.0113
# Epoch 69/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0457 - mae: 0.0420 - rmse: 0.0457 - val_loss: 0.0153 - val_mae: 0.0143 - val_rmse: 0.0151
# Epoch 70/100
# ...
# Epoch 37/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0135 - mae: 0.0111 - rmse: 0.0135 - val_loss: 0.0406 - val_mae: 0.0366 - val_rmse: 0.0407
# Epoch 38/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0148 - mae: 0.0126 - rmse: 0.0148 - val_loss: 0.0357 - val_mae: 0.0319 - val_rmse: 0.0357
# Epoch 39/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0124 - mae: 0.0102 - rmse: 0.0124 - val_loss: 0.0387 - val_mae: 0.0351 - val_rmse: 0.0386
# Epoch 40/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0131 - mae: 0.0109 - rmse: 0.0131 - val_loss: 0.0396 - val_mae: 0.0356 - val_rmse: 0.0395
#
# Epoch 00040: val_loss did not improve from 0.00729
# Epoch 41/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0138 - mae: 0.0115 - rmse: 0.0138 - val_loss: 0.0449 - val_mae: 0.0409 - val_rmse: 0.0448
# Epoch 42/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0179 - mae: 0.0158 - rmse: 0.0179 - val_loss: 0.0431 - val_mae: 0.0391 - val_rmse: 0.0429
# Epoch 43/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0141 - mae: 0.0118 - rmse: 0.0141 - val_loss: 0.0505 - val_mae: 0.0462 - val_rmse: 0.0503
# Epoch 44/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0179 - mae: 0.0158 - rmse: 0.0178 - val_loss: 0.0456 - val_mae: 0.0416 - val_rmse: 0.0452
# Epoch 45/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0150 - mae: 0.0127 - rmse: 0.0150 - val_loss: 0.0517 - val_mae: 0.0475 - val_rmse: 0.0514
#
# Epoch 00045: val_loss did not improve from 0.00729
# Epoch 46/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0172 - mae: 0.0151 - rmse: 0.0172 - val_loss: 0.0480 - val_mae: 0.0442 - val_rmse: 0.0476
# Epoch 47/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0169 - mae: 0.0148 - rmse: 0.0169 - val_loss: 0.0512 - val_mae: 0.0467 - val_rmse: 0.0507
# Epoch 48/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0162 - mae: 0.0141 - rmse: 0.0162 - val_loss: 0.0507 - val_mae: 0.0463 - val_rmse: 0.0501
# Epoch 49/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0178 - mae: 0.0157 - rmse: 0.0178 - val_loss: 0.0395 - val_mae: 0.0354 - val_rmse: 0.0392
# Epoch 50/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0217 - mae: 0.0193 - rmse: 0.0217 - val_loss: 0.0300 - val_mae: 0.0261 - val_rmse: 0.0304
#
# Epoch 00050: val_loss did not improve from 0.00729
# Epoch 51/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0224 - mae: 0.0205 - rmse: 0.0224 - val_loss: 0.0426 - val_mae: 0.0384 - val_rmse: 0.0419
# Epoch 52/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0253 - mae: 0.0231 - rmse: 0.0253 - val_loss: 0.0299 - val_mae: 0.0243 - val_rmse: 0.0305
# Epoch 53/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0209 - mae: 0.0190 - rmse: 0.0209 - val_loss: 0.0384 - val_mae: 0.0341 - val_rmse: 0.0381
# Epoch 54/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0233 - mae: 0.0210 - rmse: 0.0233 - val_loss: 0.0300 - val_mae: 0.0248 - val_rmse: 0.0305
# Epoch 55/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0187 - mae: 0.0168 - rmse: 0.0187 - val_loss: 0.0374 - val_mae: 0.0333 - val_rmse: 0.0372
#
# Epoch 00055: val_loss did not improve from 0.00729
# Epoch 56/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0201 - mae: 0.0178 - rmse: 0.0201 - val_loss: 0.0291 - val_mae: 0.0245 - val_rmse: 0.0297
# Epoch 57/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0189 - mae: 0.0169 - rmse: 0.0189 - val_loss: 0.0386 - val_mae: 0.0345 - val_rmse: 0.0383
# Epoch 58/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0196 - mae: 0.0173 - rmse: 0.0196 - val_loss: 0.0319 - val_mae: 0.0281 - val_rmse: 0.0321
# Epoch 59/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0178 - mae: 0.0157 - rmse: 0.0178 - val_loss: 0.0406 - val_mae: 0.0364 - val_rmse: 0.0402
# Epoch 60/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0181 - mae: 0.0158 - rmse: 0.0181 - val_loss: 0.0305 - val_mae: 0.0265 - val_rmse: 0.0309
#
# Epoch 00060: val_loss did not improve from 0.00729
# Epoch 61/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0176 - mae: 0.0155 - rmse: 0.0176 - val_loss: 0.0381 - val_mae: 0.0341 - val_rmse: 0.0378
# Epoch 62/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0190 - mae: 0.0167 - rmse: 0.0190 - val_loss: 0.0298 - val_mae: 0.0253 - val_rmse: 0.0303
# Epoch 63/120
# 95/95 [==============================] - 1s 13ms/step - loss: 0.0182 - mae: 0.0160 - rmse: 0.0181 - val_loss: 0.0382 - val_mae: 0.0342 - val_rmse: 0.0379
# Epoch 64/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0189 - mae: 0.0165 - rmse: 0.0189 - val_loss: 0.0312 - val_mae: 0.0272 - val_rmse: 0.0315
# Epoch 65/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0172 - mae: 0.0150 - rmse: 0.0172 - val_loss: 0.0393 - val_mae: 0.0353 - val_rmse: 0.0390
#
# Epoch 00065: val_loss did not improve from 0.00729
# Epoch 66/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0171 - mae: 0.0149 - rmse: 0.0171 - val_loss: 0.0305 - val_mae: 0.0264 - val_rmse: 0.0309
# Epoch 67/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0168 - mae: 0.0147 - rmse: 0.0168 - val_loss: 0.0365 - val_mae: 0.0326 - val_rmse: 0.0364
# Epoch 68/120
# 95/95 [==============================] - 1s 13ms/step - loss: 0.0171 - mae: 0.0147 - rmse: 0.0171 - val_loss: 0.0298 - val_mae: 0.0255 - val_rmse: 0.0303
# Epoch 69/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0170 - mae: 0.0149 - rmse: 0.0170 - val_loss: 0.0368 - val_mae: 0.0329 - val_rmse: 0.0366
# Epoch 70/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0180 - mae: 0.0157 - rmse: 0.0180 - val_loss: 0.0298 - val_mae: 0.0255 - val_rmse: 0.0302
#
# Epoch 00070: val_loss did not improve from 0.00729
# Epoch 71/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0169 - mae: 0.0149 - rmse: 0.0169 - val_loss: 0.0370 - val_mae: 0.0331 - val_rmse: 0.0368
# Epoch 72/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0169 - mae: 0.0146 - rmse: 0.0169 - val_loss: 0.0306 - val_mae: 0.0266 - val_rmse: 0.0310
# Epoch 73/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0165 - mae: 0.0144 - rmse: 0.0165 - val_loss: 0.0374 - val_mae: 0.0335 - val_rmse: 0.0372
# Epoch 74/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0163 - mae: 0.0140 - rmse: 0.0163 - val_loss: 0.0301 - val_mae: 0.0260 - val_rmse: 0.0306
# Epoch 75/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0166 - mae: 0.0144 - rmse: 0.0165 - val_loss: 0.0366 - val_mae: 0.0328 - val_rmse: 0.0365
#
# Epoch 00075: val_loss did not improve from 0.00729
# Epoch 76/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0163 - mae: 0.0140 - rmse: 0.0163 - val_loss: 0.0304 - val_mae: 0.0263 - val_rmse: 0.0308
# Epoch 77/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0169 - mae: 0.0147 - rmse: 0.0169 - val_loss: 0.0378 - val_mae: 0.0338 - val_rmse: 0.0375
# Epoch 78/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0169 - mae: 0.0145 - rmse: 0.0169 - val_loss: 0.0314 - val_mae: 0.0275 - val_rmse: 0.0318
# Epoch 79/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0168 - mae: 0.0146 - rmse: 0.0167 - val_loss: 0.0380 - val_mae: 0.0341 - val_rmse: 0.0377
# Epoch 80/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0161 - mae: 0.0138 - rmse: 0.0161 - val_loss: 0.0311 - val_mae: 0.0271 - val_rmse: 0.0315
#
# Epoch 00080: val_loss did not improve from 0.00729
# Epoch 81/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0166 - mae: 0.0144 - rmse: 0.0165 - val_loss: 0.0371 - val_mae: 0.0332 - val_rmse: 0.0369
# Epoch 82/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0161 - mae: 0.0137 - rmse: 0.0161 - val_loss: 0.0306 - val_mae: 0.0265 - val_rmse: 0.0310
# Epoch 83/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0168 - mae: 0.0146 - rmse: 0.0167 - val_loss: 0.0371 - val_mae: 0.0332 - val_rmse: 0.0370
# Epoch 84/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0165 - mae: 0.0142 - rmse: 0.0165 - val_loss: 0.0313 - val_mae: 0.0274 - val_rmse: 0.0317
# Epoch 85/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0169 - mae: 0.0147 - rmse: 0.0168 - val_loss: 0.0376 - val_mae: 0.0337 - val_rmse: 0.0374
#
# Epoch 00085: val_loss did not improve from 0.00729
# Epoch 86/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0164 - mae: 0.0141 - rmse: 0.0165 - val_loss: 0.0320 - val_mae: 0.0281 - val_rmse: 0.0323
# Epoch 87/120
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0167 - mae: 0.0146 - rmse: 0.0167 - val_loss: 0.0377 - val_mae: 0.0338 - val_rmse: 0.0375
# Epoch 88/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0161 - mae: 0.0138 - rmse: 0.0161 - val_loss: 0.0314 - val_mae: 0.0273 - val_rmse: 0.0317
# Epoch 89/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0164 - mae: 0.0143 - rmse: 0.0164 - val_loss: 0.0373 - val_mae: 0.0334 - val_rmse: 0.0372
# Epoch 90/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0157 - mae: 0.0134 - rmse: 0.0157 - val_loss: 0.0316 - val_mae: 0.0277 - val_rmse: 0.0319
#
# Epoch 00090: val_loss did not improve from 0.00729
# Epoch 91/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0170 - mae: 0.0149 - rmse: 0.0170 - val_loss: 0.0385 - val_mae: 0.0345 - val_rmse: 0.0383
# Epoch 92/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0167 - mae: 0.0143 - rmse: 0.0167 - val_loss: 0.0340 - val_mae: 0.0303 - val_rmse: 0.0342
# Epoch 93/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0172 - mae: 0.0151 - rmse: 0.0172 - val_loss: 0.0391 - val_mae: 0.0349 - val_rmse: 0.0388
# Epoch 94/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0166 - mae: 0.0143 - rmse: 0.0166 - val_loss: 0.0327 - val_mae: 0.0286 - val_rmse: 0.0329
# Epoch 95/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0164 - mae: 0.0142 - rmse: 0.0164 - val_loss: 0.0376 - val_mae: 0.0337 - val_rmse: 0.0375
#
# Epoch 00095: val_loss did not improve from 0.00729
# Epoch 96/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0148 - mae: 0.0124 - rmse: 0.0148 - val_loss: 0.0336 - val_mae: 0.0298 - val_rmse: 0.0338
# Epoch 97/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0171 - mae: 0.0149 - rmse: 0.0171 - val_loss: 0.0394 - val_mae: 0.0353 - val_rmse: 0.0391
# Epoch 98/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0165 - mae: 0.0142 - rmse: 0.0165 - val_loss: 0.0336 - val_mae: 0.0298 - val_rmse: 0.0338
# Epoch 99/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0174 - mae: 0.0153 - rmse: 0.0174 - val_loss: 0.0393 - val_mae: 0.0352 - val_rmse: 0.0391
# Epoch 100/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0167 - mae: 0.0144 - rmse: 0.0167 - val_loss: 0.0318 - val_mae: 0.0277 - val_rmse: 0.0321
#
# Epoch 00100: val_loss did not improve from 0.00729
# Epoch 101/120
# 95/95 [==============================] - 1s 13ms/step - loss: 0.0165 - mae: 0.0144 - rmse: 0.0164 - val_loss: 0.0382 - val_mae: 0.0342 - val_rmse: 0.0379
# Epoch 102/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0156 - mae: 0.0133 - rmse: 0.0156 - val_loss: 0.0323 - val_mae: 0.0283 - val_rmse: 0.0326
# Epoch 103/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0169 - mae: 0.0147 - rmse: 0.0169 - val_loss: 0.0393 - val_mae: 0.0352 - val_rmse: 0.0390
# Epoch 104/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0165 - mae: 0.0142 - rmse: 0.0165 - val_loss: 0.0335 - val_mae: 0.0297 - val_rmse: 0.0337
# Epoch 105/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0170 - mae: 0.0149 - rmse: 0.0170 - val_loss: 0.0394 - val_mae: 0.0352 - val_rmse: 0.0391
#
# Epoch 00105: val_loss did not improve from 0.00729
# Epoch 106/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0165 - mae: 0.0142 - rmse: 0.0165 - val_loss: 0.0324 - val_mae: 0.0282 - val_rmse: 0.0327
# Epoch 107/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0159 - mae: 0.0138 - rmse: 0.0158 - val_loss: 0.0379 - val_mae: 0.0339 - val_rmse: 0.0377
# Epoch 108/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0141 - mae: 0.0118 - rmse: 0.0141 - val_loss: 0.0348 - val_mae: 0.0310 - val_rmse: 0.0348
# Epoch 109/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0150 - mae: 0.0129 - rmse: 0.0150 - val_loss: 0.0382 - val_mae: 0.0343 - val_rmse: 0.0379
# Epoch 110/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0131 - mae: 0.0108 - rmse: 0.0131 - val_loss: 0.0368 - val_mae: 0.0331 - val_rmse: 0.0366
#
# Epoch 00110: val_loss did not improve from 0.00729
# Epoch 111/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0151 - mae: 0.0129 - rmse: 0.0150 - val_loss: 0.0387 - val_mae: 0.0347 - val_rmse: 0.0384
# Epoch 112/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0155 - mae: 0.0132 - rmse: 0.0155 - val_loss: 0.0318 - val_mae: 0.0270 - val_rmse: 0.0322
# Epoch 113/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0147 - mae: 0.0126 - rmse: 0.0147 - val_loss: 0.0363 - val_mae: 0.0323 - val_rmse: 0.0362
# Epoch 114/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0137 - mae: 0.0115 - rmse: 0.0137 - val_loss: 0.0370 - val_mae: 0.0331 - val_rmse: 0.0368
# Epoch 115/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0134 - mae: 0.0112 - rmse: 0.0134 - val_loss: 0.0388 - val_mae: 0.0350 - val_rmse: 0.0385
#
# Epoch 00115: val_loss did not improve from 0.00729
# Epoch 116/120
# 95/95 [==============================] - 1s 13ms/step - loss: 0.0140 - mae: 0.0119 - rmse: 0.0140 - val_loss: 0.0392 - val_mae: 0.0352 - val_rmse: 0.0388
# Epoch 117/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0131 - mae: 0.0108 - rmse: 0.0131 - val_loss: 0.0427 - val_mae: 0.0389 - val_rmse: 0.0421
# Epoch 118/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0131 - mae: 0.0108 - rmse: 0.0131 - val_loss: 0.0412 - val_mae: 0.0371 - val_rmse: 0.0407
# Epoch 119/120
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0143 - mae: 0.0119 - rmse: 0.0143 - val_loss: 0.0416 - val_mae: 0.0378 - val_rmse: 0.0411
# Epoch 120/120
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0138 - mae: 0.0116 - rmse: 0.0138 - val_loss: 0.0423 - val_mae: 0.0382 - val_rmse: 0.0418
#
# Epoch 00120: val_loss did not improve from 0.00729
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0683 - mae: 0.0599 - rmse: 0.0679
# [array([[2489.7068, 2492.7725]], dtype=float32), array([[2498.1628, 2501.0906]], dtype=float32), array([[2509.483 , 2512.3716]], dtype=float32), array([[2522.7212, 2525.6243]], dtype=float32), array([[2535.5696, 2538.452 ]], dtype=float32), array([[2547.624 , 2550.4458]], dtype=float32), array([[2558.9778, 2561.7368]], dtype=float32), array([[2570.5378, 2573.2598]], dtype=float32), array([[2582.28  , 2584.9678]], dtype=float32), array([[2594.1309, 2596.7686]], dtype=float32), array([[2605.949, 2608.521]], dtype=float32), array([[2617.4773, 2619.976 ]], dtype=float32), array([[2628.6272, 2631.0522]], dtype=float32), array([[2639.2578, 2641.6096]], dtype=float32), array([[2649.254 , 2651.5344]], dtype=float32)]
# [2489.7068, 2498.1628, 2509.483, 2522.7212, 2535.5696, 2547.624, 2558.9778, 2570.5378, 2582.28, 2594.1309, 2605.949, 2617.4773, 2628.6272, 2639.2578, 2649.254]

# %%
id_tunning = 1
id_split =1

final_dict = {}

for r in record:
#print(tunning_dict[1]['epochs'])
  loss = []
  mae =[]
  rmse = []
  val_loss = []
  val_mae = []
  val_rmse = []

  for h in record[r]:
    #print("Tunning ID:  ",id_tunning," Split ID: ",id_split)
    #plot_learning_curves(h, tunning_dict[id_tunning]['epochs'])
    #['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse']
    #print("loss: ",sum(h.history['loss'])/len(h.history['loss'])," MAE: ",sum(h.history['mae'])/len(h.history['mae'])," RMSE: ",sum(h.history['rmse'])/len(h.history['rmse'])," VAL_LOSS: ",sum(h.history['val_loss'])/len(h.history['val_loss'])," VAL_MAE: ",sum(h.history['val_mae'])/len(h.history['val_mae'])," VAL_RMSE: ",sum(h.history['val_rmse'])/len(h.history['val_rmse']))
    loss.append(sum(h.history['loss'])/len(h.history['loss']))
    mae.append(sum(h.history['mae'])/len(h.history['mae']))
    rmse.append(sum(h.history['rmse'])/len(h.history['rmse']))
    val_loss.append(sum(h.history['val_loss'])/len(h.history['val_loss']))
    val_mae.append(sum(h.history['val_mae'])/len(h.history['val_mae']))
    val_rmse.append(sum(h.history['val_rmse'])/len(h.history['val_rmse']))
    id_split+=1
  id_split=1
  
  final_dict[id_tunning]=[sum(loss)/len(loss), sum(mae)/len(mae),sum(rmse)/len(rmse),sum(val_loss)/len(val_loss),sum(val_mae)/len(val_mae), sum(val_rmse)/len(val_rmse)]

  id_tunning=id_tunning+1

# %%
for f in final_dict:
  print("Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE")
  print("ID tunning: ",f, " Valores: ",final_dict[f],"\n")
# Out:
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  1  Valores:  [0.07732811321814854, 0.07426746400694052, 0.07716539154450099, 0.05273082256317139, 0.04937463970854878, 0.052681857347488405]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  2  Valores:  [0.04372657176107168, 0.041421650337676204, 0.043635797326763474, 0.04220917784298459, 0.039733354796965915, 0.042227617731938755]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  3  Valores:  [0.033821643438811104, 0.03159193245694041, 0.03375472504956027, 0.04077800490893423, 0.038140432415530084, 0.04087424618968119]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  4  Valores:  [0.04079859992489219, 0.038333371902505554, 0.04068617176057564, 0.04743227747838116, 0.04466886631368349, 0.048178708656794494]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  5  Valores:  [0.034907993201718286, 0.032547718938440086, 0.034828029876505885, 0.045046810938597276, 0.04248313366056041, 0.04546846257936624]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  6  Valores:  [0.031354523015518984, 0.02899467719253153, 0.03126531751412484, 0.037212055150626436, 0.03467441672368699, 0.03758741337159235]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  7  Valores:  [0.03677000395332774, 0.03321776646499833, 0.03664075373361508, 0.020571930557489394, 0.017509961525599162, 0.020937082730233664]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  8  Valores:  [0.02961413353267643, 0.026470412131122972, 0.029513787005648568, 0.02252170320910712, 0.019889788072625245, 0.022784680955939825]
#
# Loss | MAE | RMSE | VAL_LOSS | VAL_MAE | VAL_RMSE
# ID tunning:  9  Valores:  [0.027739972168476217, 0.024701557132518953, 0.027631792555459667, 0.02159607390640304, 0.018974127943834497, 0.021919187329088652]

# %%
print(final_dict)
# Out:
# {1: [0.07732811321814854, 0.07426746400694052, 0.07716539154450099, 0.05273082256317139, 0.04937463970854878, 0.052681857347488405], 2: [0.04372657176107168, 0.041421650337676204, 0.043635797326763474, 0.04220917784298459, 0.039733354796965915, 0.042227617731938755], 3: [0.033821643438811104, 0.03159193245694041, 0.03375472504956027, 0.04077800490893423, 0.038140432415530084, 0.04087424618968119], 4: [0.04079859992489219, 0.038333371902505554, 0.04068617176057564, 0.04743227747838116, 0.04466886631368349, 0.048178708656794494], 5: [0.034907993201718286, 0.032547718938440086, 0.034828029876505885, 0.045046810938597276, 0.04248313366056041, 0.04546846257936624], 6: [0.031354523015518984, 0.02899467719253153, 0.03126531751412484, 0.037212055150626436, 0.03467441672368699, 0.03758741337159235], 7: [0.03677000395332774, 0.03321776646499833, 0.03664075373361508, 0.020571930557489394, 0.017509961525599162, 0.020937082730233664], 8: [0.02961413353267643, 0.026470412131122972, 0.029513787005648568, 0.02252170320910712, 0.019889788072625245, 0.022784680955939825], 9: [0.027739972168476217, 0.024701557132518953, 0.027631792555459667, 0.02159607390640304, 0.018974127943834497, 0.021919187329088652]}

# %%
final_df = pd.DataFrame.from_dict(final_dict, orient='index')
final_df.columns = ['Loss','MAE','RMSE','VAL_LOSS','VAL_MAE','VAL_RMSE']
final_df
# Out:
#        Loss       MAE      RMSE  VAL_LOSS   VAL_MAE  VAL_RMSE
# 1  0.077328  0.074267  0.077165  0.052731  0.049375  0.052682
# 2  0.043727  0.041422  0.043636  0.042209  0.039733  0.042228
# 3  0.033822  0.031592  0.033755  0.040778  0.038140  0.040874
# 4  0.040799  0.038333  0.040686  0.047432  0.044669  0.048179
# 5  0.034908  0.032548  0.034828  0.045047  0.042483  0.045468
# 6  0.031355  0.028995  0.031265  0.037212  0.034674  0.037587
# 7  0.036770  0.033218  0.036641  0.020572  0.017510  0.020937
# 8  0.029614  0.026470  0.029514  0.022522  0.019890  0.022785
# 9  0.027740  0.024702  0.027632  0.021596  0.018974  0.021919

# %%
final_df.to_csv(r"resultados.csv",index=True)
